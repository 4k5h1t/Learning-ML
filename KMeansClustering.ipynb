# %% [markdown]
# <a href="https://colab.research.google.com/github/4k5h1t/Learning-ML/blob/main/KMeansClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![MLoriginal.png](data:image/png;base64,...)

# %% [markdown]
# # Topics
# 1.   Types of Clustering
# 2.   Steps in Clustering
# 1.   K-Means Clustering
# 2.   Advantages and Disadvantages
# 5. Implementation in Python

# %% [markdown]
# # 1. Types of Clustering
#
# Refer : https://developers.google.com/machine-learning/clustering/clustering-algorithms
#
# There are several types of clustering like :
#
# > Centroid-based Clustering:
# >>Centroid-based clustering organizes the data into non-hierarchical clusters, in contrast to hierarchical clustering defined below. k-means is the most widely-used centroid-based clustering algorithm. Centroid-based algorithms are efficient but sensitive to initial conditions and outliers.
#
# >Density-based Clustering:
# >>Density-based clustering connects areas of high example density into clusters. This allows for arbitrary-shaped distributions as long as dense areas can be connected. These algorithms have difficulty with data of varying densities and high dimensions. Further, by design, these algorithms do not assign outliers to clusters.
#
# >Distribution-based Clustering:
# >>This clustering approach assumes data is composed of distributions, such as Gaussian distributions. As distance from the distribution's center increases, the probability that a point belongs to the distribution decreases. The bands show that decrease in probability. When you do not know the type of distribution in your data, you should use a different algorithm.
#
# >Hierarchical Clustering:
# >>Hierarchical clustering creates a tree of clusters. Hierarchical clustering, not surprisingly, is well suited to hierarchical data, such as taxonomies. In addition, another advantage is that any number of clusters can be chosen by cutting the tree at the right level.

# %% [markdown]
# Our topic of interest is K-Means Clustering (Centroid Based Clustering)
# # 2. Steps in Clustering
#
#
# 1.   Preprocess Data (Removing or Replacing or Scaling )
# 2.   Create Similarity Metric (Ex: Eucledian Distance)
# 3. Run Clustering Algorithm (Stopping criteria can be number of iterations)
# 4. Interpret Results (Visualizing using matplotlib or other libraries)

# %% [markdown]
# # 3. K-Means Clustering
# To group data into $k$ clusters, K-Means perform as follows,
#
# **Steps**
#
#
# 1.   Randomly chose centroid for each cluster
# 2.   Assign each sample to closest centroid based on Similarity Metric (Eucledian Distance)
# 3. For each cluster, recompute centroid, by taking average of all samples in that cluster
# 4. Repeat 2 and 3 until stopping criteria is met (Ex : 50 iterations)

# %% [markdown]
# # 4. Simple Numerical Example
# ![K-Means.PNG](data:image/png;base64,...)
#
# The example shows the result after iteration $1$.
#
# This process will be repeated till stopping criteria is met

# %% [markdown]
# #5. Implementing the simple example in Python

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [5, 3],[5, 6]]) #Samples
start1=np.array([[1,2],[1,4]]) #Centroid-1
kmeans = KMeans(n_clusters=2,max_iter=1,init=start1).fit(X)  #Defining and fitting K-means

print(kmeans.labels_) #Will print Cluster allocation of each samples
print(kmeans.predict([[0, 0], [12, 3]])) #Predicting for unseen data
print(kmeans.cluster_centers_) #Centroids after iteration 1
# Out:
# [0 1 0 1]
# [0 0]
# [[3.  2.5]
#  [3.  5. ]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   """

# %% [markdown]
# ## Visualizing results after iteration 1

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %% [markdown]
# Do you think the visualization above is satisfying our Logic?. Justify Your Answer
#
# The above visualization does seem to satisfy our logic as the members classified as being of the green cluster are noticably closer to each other than the blue cluster, and vice versa

# %% [markdown]
# ## Sample Example with Default values

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [5, 3],[5, 6]]) #Samples
kmeans = KMeans(n_clusters=2).fit(X)  #Defining and fitting K-means

print(kmeans.labels_) #Will print Cluster allocation of each samples
print(kmeans.predict([[0, 0], [12, 3]])) #Predicting for unseen data
print(kmeans.cluster_centers_) 

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()
# Out:
# [0 0 1 1]
# [0 1]
# [[1.  3. ]
#  [5.  4.5]]

# %% [markdown]
# #6. Assignment

# %%
#Implement K-Means for following data, Assume k=2 and Visualize the results
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [1, 0], [10, 2], [10, 4], [10, 0], [5,3], [7,2]])

kmeans = KMeans(n_clusters=2).fit(X)

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %%
#Implement K-Means for following data, Assume k=3 and Visualize the results
X = np.array([[1, 2], [1, 4], [1, 0], [10, 2], [10, 4], [10, 0], [5,3], [7,2]])

kmeans = KMeans(n_clusters=3).fit(X)

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X[kmeans.labels_ == 0, 0], X[kmeans.labels_ == 0, 1], c='green', label='cluster 1')
plt.scatter(X[kmeans.labels_ == 1, 0], X[kmeans.labels_ == 1, 1], c='blue', label='cluster 2')
plt.scatter(X[kmeans.labels_ == 2, 0], X[kmeans.labels_ == 2, 1], c='black', label='cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300,  c='r', label='centroid')
plt.legend()

# %% [markdown]
# # 7. K-means on Simple dataset
#
# For Dataset visit link
#
# https://raw.githubusercontent.com/Jayku88/Machine-Learning-Lab/main/faithful.csv
#
# Right Click and Save As to location in your System

# %%
#Upload file to colab from your system
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c97c5ecb-4ef9-46b5-98f6-1a6230cf394d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c97c5ecb-4ef9-46b5-98f6-1a6230cf394d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving faithful.csv to faithful.csv

# %%
#Converting to Dataframe
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['faithful.csv']))

# %%
#Visualizing Input Data
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1])
plt.xlabel('Eruption time in mins')
plt.ylabel('Waiting time to next eruption')
plt.title('Visualization of raw data');

# %%
#K-Means Clustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Standardize the data
X_std = StandardScaler().fit_transform(df)

# Run local implementation of kmeans
km = KMeans(n_clusters=2)
km.fit(X_std)
centroids = km.cluster_centers_

# Plot the clustered data
fig, ax = plt.subplots(figsize=(6, 6))
plt.scatter(X_std[km.labels_ == 0, 0], X_std[km.labels_ == 0, 1],c='green', label='cluster 1')
plt.scatter(X_std[km.labels_ == 1, 0], X_std[km.labels_ == 1, 1],c='blue', label='cluster 2')
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], marker='*', s=300, c='r', label='centroid')
plt.legend()
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.xlabel('Eruption time in mins')
plt.ylabel('Waiting time to next eruption')
plt.title('Visualization of clustered data', fontweight='bold')
ax.set_aspect('equal');

# %% [markdown]
# # 8. Advantages and Disadvantages of K-Means Clustering
#
# Refer : https://developers.google.com/machine-learning/clustering/algorithm/advantages-disadvantages
#
# The Advantages of k-means are as follows :
#
# >Relatively simple to implement.
#
# >Scales to large data sets.
#
# >Guarantees convergence.
#
# >Can warm-start the positions of centroids.
#
# >Easily adapts to new examples.
#
# >Generalizes to clusters of different shapes and sizes, such as elliptical clusters.
#
#
# The Disadvantages of k-means are as follows :
#
# >Choosing k manually.
# >>Use the “Loss vs. Clusters” plot to find the optimal (k), as discussed in Interpret Results.
#
# >Being dependent on initial values.
# >>For a low k, you can mitigate this dependence by running k-means several times with different initial values and picking the best result. As k increases, you need advanced versions of k-means to pick better values of the initial centroids (called k-means seeding).
#
# >Clustering data of varying sizes and density.
# >>k-means has trouble clustering data where clusters are of varying sizes and density. To cluster such data, you need to generalize k-means.
#
# >Clustering outliers.
# >>Centroids can be dragged by outliers, or outliers might get their own cluster instead of being ignored. Consider removing or clipping outliers before clustering.
#
# >Scaling with number of dimensions.
# >>As the number of dimensions increases, a distance-based similarity measure converges to a constant value between any given examples. Reduce dimensionality either by using PCA on the feature data, or by using “spectral clustering” to modify the clustering algorithm as explained below.

# %% [markdown]
# # Reflections
#
#
# 1.   K-Means Clustering
# 2.   Reading csv files and processing
# 1.   Visualizing K-Means results using matplotlib
# 2.   Advantages and Disadvantages of K-Means

# %%
#@title  { run: "auto", vertical-output: true }
#@title  { run: "auto", vertical-output: true }
name = "Akshit Sudheer Kumar" #@param {type:"string"}
roll_number = "AM.EN.U4AIE20110" #@param {type:"string"}
self_assessment = 10 #@param {type:"slider", min:1, max:10, step:1}
print("Name : ",name)
print("Roll Number : ",roll_number)
print("Self Assessment Marks : ",self_assessment,"/10")
# Out:
# Name :  Akshit Sudheer Kumar
# Roll Number :  AM.EN.U4AIE20110
# Self Assessment Marks :  10 /10
